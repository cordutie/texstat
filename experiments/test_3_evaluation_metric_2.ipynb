# %%
# Add the parent directory to the Python path
import sys
import os
parent_dir = os.path.abspath('..')
if parent_dir not in sys.path:
    sys.path.append(parent_dir)

# Import loss function
from texstat.fad import *

#Initilize the FAD computation
# Texstat model parameters
sr              = 44100
frame_size      = 44100
FAD_texstat = FAD_wrapper(frame_size = frame_size, sampling_rate = sr, device='cpu')

def compute_fad_for_all_pairs(folder_path):
    """Computes FAD for all pairs folders"""
    # Create list of all folders in the given directory
    folders = [f for f in os.listdir(folder_path) if os.path.isdir(os.path.join(folder_path, f))]
    print(f"Found {len(folders)} folders in {folder_path}.")
    result = []
    # Iterate through all pairs of folders
    for i in range(len(folders)):
        for j in range(i + 1, len(folders)):
            folder_1 = folders[i]
            folder_2 = folders[j]
            # Compute FAD score
            fad_score = FAD_texstat.score(
                os.path.join(folder_path, folder_1),
                os.path.join(folder_path, folder_2),
                segments_number=100
            )
            # Print the result
            print(f"{folder_1:<20} {folder_2:<20} {fad_score:.5f}")  
            result.append((folder_1, folder_2, fad_score))     
    # Print results as a formatted table
    print("\nComputed FAD Scores:")
    print("=" * 50)
    print(f"{'File 1':<20} {'File 2':<20} {'FAD Score'}")
    print("=" * 50)
    for folder_1, folder_2, fad_score in result:
        print(f"{folder_1:<20} {folder_2:<20} {fad_score:.5f}")

folder_path = "../../MicroTex/freesound_class/"
compute_fad_for_all_pairs(folder_path)
# Out:
# Found 6 folders in ../../MicroTex/freesound_class/.
# Processing folder: keyboard
# Found 3 files in ../../MicroTex/freesound_class/keyboard
#     Segmented 38 segments from ../../MicroTex/freesound_class/keyboard/keyboard_ceramic.wav
#     Segmented 183 segments from ../../MicroTex/freesound_class/keyboard/keyboard_mechanic.wav
#     Segmented 27 segments from ../../MicroTex/freesound_class/keyboard/keyboard_yellow.wav
# Total segments: 248
# Selected 100 segments after random selection
# Processed 100 segments in ../../MicroTex/freesound_class/keyboard
# Processing folder: water
# Found 2 files in ../../MicroTex/freesound_class/water
#     Segmented 191 segments from ../../MicroTex/freesound_class/water/water_augmented_2.wav
#     Segmented 48 segments from ../../MicroTex/freesound_class/water/water.wav
# Total segments: 239
# Selected 100 segments after random selection
# Processed 100 segments in ../../MicroTex/freesound_class/water
# keyboard             water                24.36440
# Processing folder: keyboard
# Found 3 files in ../../MicroTex/freesound_class/keyboard
#     Segmented 38 segments from ../../MicroTex/freesound_class/keyboard/keyboard_ceramic.wav
#     Segmented 183 segments from ../../MicroTex/freesound_class/keyboard/keyboard_mechanic.wav
#     Segmented 27 segments from ../../MicroTex/freesound_class/keyboard/keyboard_yellow.wav
# Total segments: 248
# Selected 100 segments after random selection
# Processed 100 segments in ../../MicroTex/freesound_class/keyboard
# Processing folder: wind
# Found 2 files in ../../MicroTex/freesound_class/wind
#     Segmented 44 segments from ../../MicroTex/freesound_class/wind/wind_interior.wav
#     Segmented 1185 segments from ../../MicroTex/freesound_class/wind/wind_exterior.wav
# Total segments: 1229
# Selected 100 segments after random selection
# Processed 100 segments in ../../MicroTex/freesound_class/wind
# keyboard             wind                 36.11030
# Processing folder: keyboard
# Found 3 files in ../../MicroTex/freesound_class/keyboard
#     Segmented 38 segments from ../../MicroTex/freesound_class/keyboard/keyboard_ceramic.wav
#     Segmented 183 segments from ../../MicroTex/freesound_class/keyboard/keyboard_mechanic.wav
#     Segmented 27 segments from ../../MicroTex/freesound_class/keyboard/keyboard_yellow.wav
# Total segments: 248
# Selected 100 segments after random selection
# Processed 100 segments in ../../MicroTex/freesound_class/keyboard
# Processing folder: fire
# Found 1 files in ../../MicroTex/freesound_class/fire
#     Segmented 191 segments from ../../MicroTex/freesound_class/fire/fire_augmented.wav
# Total segments: 191
# Selected 100 segments after random selection
# Processed 100 segments in ../../MicroTex/freesound_class/fire
# keyboard             fire                 5.20723
# Processing folder: keyboard
# Found 3 files in ../../MicroTex/freesound_class/keyboard
#     Segmented 38 segments from ../../MicroTex/freesound_class/keyboard/keyboard_ceramic.wav
#     Segmented 183 segments from ../../MicroTex/freesound_class/keyboard/keyboard_mechanic.wav
#     Segmented 27 segments from ../../MicroTex/freesound_class/keyboard/keyboard_yellow.wav
# Total segments: 248
# Selected 100 segments after random selection
# Processed 100 segments in ../../MicroTex/freesound_class/keyboard
# Processing folder: rain
# Found 1 files in ../../MicroTex/freesound_class/rain
#     Segmented 123 segments from ../../MicroTex/freesound_class/rain/rain.wav
# Total segments: 123
# Selected 100 segments after random selection
# Processed 100 segments in ../../MicroTex/freesound_class/rain
# keyboard             rain                 26.07075
# Processing folder: keyboard
# Found 3 files in ../../MicroTex/freesound_class/keyboard
#     Segmented 38 segments from ../../MicroTex/freesound_class/keyboard/keyboard_ceramic.wav
#     Segmented 183 segments from ../../MicroTex/freesound_class/keyboard/keyboard_mechanic.wav
#     Segmented 27 segments from ../../MicroTex/freesound_class/keyboard/keyboard_yellow.wav
# Total segments: 248
# Selected 100 segments after random selection
# Processed 100 segments in ../../MicroTex/freesound_class/keyboard
# Processing folder: bubbles
# Found 2 files in ../../MicroTex/freesound_class/bubbles
#     Segmented 59 segments from ../../MicroTex/freesound_class/bubbles/bubbles_short_extended.wav
#     Segmented 242 segments from ../../MicroTex/freesound_class/bubbles/bubbles_long.wav
# Total segments: 301
# Selected 100 segments after random selection
# Processed 100 segments in ../../MicroTex/freesound_class/bubbles
# keyboard             bubbles              21.41910
# Processing folder: water
# Found 2 files in ../../MicroTex/freesound_class/water
#     Segmented 191 segments from ../../MicroTex/freesound_class/water/water_augmented_2.wav
#     Segmented 48 segments from ../../MicroTex/freesound_class/water/water.wav
# Total segments: 239
# Selected 100 segments after random selection
# Processed 100 segments in ../../MicroTex/freesound_class/water
# Processing folder: wind
# Found 2 files in ../../MicroTex/freesound_class/wind
#     Segmented 44 segments from ../../MicroTex/freesound_class/wind/wind_interior.wav
#     Segmented 1185 segments from ../../MicroTex/freesound_class/wind/wind_exterior.wav
# Total segments: 1229
# Selected 100 segments after random selection
# Processed 100 segments in ../../MicroTex/freesound_class/wind
# water                wind                 2.67403
# Processing folder: water
# Found 2 files in ../../MicroTex/freesound_class/water
#     Segmented 191 segments from ../../MicroTex/freesound_class/water/water_augmented_2.wav
#     Segmented 48 segments from ../../MicroTex/freesound_class/water/water.wav
# Total segments: 239
# Selected 100 segments after random selection
# Processed 100 segments in ../../MicroTex/freesound_class/water
# Processing folder: fire
# Found 1 files in ../../MicroTex/freesound_class/fire
#     Segmented 191 segments from ../../MicroTex/freesound_class/fire/fire_augmented.wav
# Total segments: 191
# Selected 100 segments after random selection
# Processed 100 segments in ../../MicroTex/freesound_class/fire
# water                fire                 25.34158
# Processing folder: water
# Found 2 files in ../../MicroTex/freesound_class/water
#     Segmented 191 segments from ../../MicroTex/freesound_class/water/water_augmented_2.wav
#     Segmented 48 segments from ../../MicroTex/freesound_class/water/water.wav
# Total segments: 239
# Selected 100 segments after random selection
# Processed 100 segments in ../../MicroTex/freesound_class/water
# Processing folder: rain
# Found 1 files in ../../MicroTex/freesound_class/rain
#     Segmented 123 segments from ../../MicroTex/freesound_class/rain/rain.wav
# Total segments: 123
# Selected 100 segments after random selection
# Processed 100 segments in ../../MicroTex/freesound_class/rain
# water                rain                 1.08838
# Processing folder: water
# Found 2 files in ../../MicroTex/freesound_class/water
#     Segmented 191 segments from ../../MicroTex/freesound_class/water/water_augmented_2.wav
#     Segmented 48 segments from ../../MicroTex/freesound_class/water/water.wav
# Total segments: 239
# Selected 100 segments after random selection
# Processed 100 segments in ../../MicroTex/freesound_class/water
# Processing folder: bubbles
# Found 2 files in ../../MicroTex/freesound_class/bubbles
#     Segmented 59 segments from ../../MicroTex/freesound_class/bubbles/bubbles_short_extended.wav
#     Segmented 242 segments from ../../MicroTex/freesound_class/bubbles/bubbles_long.wav
# Total segments: 301
# Selected 100 segments after random selection
# Processed 100 segments in ../../MicroTex/freesound_class/bubbles
# water                bubbles              2.68151
# Processing folder: wind
# Found 2 files in ../../MicroTex/freesound_class/wind
#     Segmented 44 segments from ../../MicroTex/freesound_class/wind/wind_interior.wav
#     Segmented 1185 segments from ../../MicroTex/freesound_class/wind/wind_exterior.wav
# Total segments: 1229
# Selected 100 segments after random selection
# Processed 100 segments in ../../MicroTex/freesound_class/wind
# Processing folder: fire
# Found 1 files in ../../MicroTex/freesound_class/fire
#     Segmented 191 segments from ../../MicroTex/freesound_class/fire/fire_augmented.wav
# Total segments: 191
# Selected 100 segments after random selection
# Processed 100 segments in ../../MicroTex/freesound_class/fire
# wind                 fire                 35.63640
# Processing folder: wind
# Found 2 files in ../../MicroTex/freesound_class/wind
#     Segmented 44 segments from ../../MicroTex/freesound_class/wind/wind_interior.wav
#     Segmented 1185 segments from ../../MicroTex/freesound_class/wind/wind_exterior.wav
# Total segments: 1229
# Selected 100 segments after random selection
# Processed 100 segments in ../../MicroTex/freesound_class/wind
# Processing folder: rain
# Found 1 files in ../../MicroTex/freesound_class/rain
#     Segmented 123 segments from ../../MicroTex/freesound_class/rain/rain.wav
# Total segments: 123
# Selected 100 segments after random selection
# Processed 100 segments in ../../MicroTex/freesound_class/rain
# wind                 rain                 2.35080
# Processing folder: wind
# Found 2 files in ../../MicroTex/freesound_class/wind
#     Segmented 44 segments from ../../MicroTex/freesound_class/wind/wind_interior.wav
#     Segmented 1185 segments from ../../MicroTex/freesound_class/wind/wind_exterior.wav
# Total segments: 1229
# Selected 100 segments after random selection
# Processed 100 segments in ../../MicroTex/freesound_class/wind
# Processing folder: bubbles
# Found 2 files in ../../MicroTex/freesound_class/bubbles
#     Segmented 59 segments from ../../MicroTex/freesound_class/bubbles/bubbles_short_extended.wav
#     Segmented 242 segments from ../../MicroTex/freesound_class/bubbles/bubbles_long.wav
# Total segments: 301
# Selected 100 segments after random selection
# Processed 100 segments in ../../MicroTex/freesound_class/bubbles
# wind                 bubbles              6.45947
# Processing folder: fire
# Found 1 files in ../../MicroTex/freesound_class/fire
#     Segmented 191 segments from ../../MicroTex/freesound_class/fire/fire_augmented.wav
# Total segments: 191
# Selected 100 segments after random selection
# Processed 100 segments in ../../MicroTex/freesound_class/fire
# Processing folder: rain
# Found 1 files in ../../MicroTex/freesound_class/rain
#     Segmented 123 segments from ../../MicroTex/freesound_class/rain/rain.wav
# Total segments: 123
# Selected 100 segments after random selection
# Processed 100 segments in ../../MicroTex/freesound_class/rain
# fire                 rain                 28.25837
# Processing folder: fire
# Found 1 files in ../../MicroTex/freesound_class/fire
#     Segmented 191 segments from ../../MicroTex/freesound_class/fire/fire_augmented.wav
# Total segments: 191
# Selected 100 segments after random selection
# Processed 100 segments in ../../MicroTex/freesound_class/fire
# Processing folder: bubbles
# Found 2 files in ../../MicroTex/freesound_class/bubbles
#     Segmented 59 segments from ../../MicroTex/freesound_class/bubbles/bubbles_short_extended.wav
#     Segmented 242 segments from ../../MicroTex/freesound_class/bubbles/bubbles_long.wav
# Total segments: 301
# Selected 100 segments after random selection
# Processed 100 segments in ../../MicroTex/freesound_class/bubbles
# fire                 bubbles              23.24597
# Processing folder: rain
# Found 1 files in ../../MicroTex/freesound_class/rain
#     Segmented 123 segments from ../../MicroTex/freesound_class/rain/rain.wav
# Total segments: 123
# Selected 100 segments after random selection
# Processed 100 segments in ../../MicroTex/freesound_class/rain
# Processing folder: bubbles
# Found 2 files in ../../MicroTex/freesound_class/bubbles
#     Segmented 59 segments from ../../MicroTex/freesound_class/bubbles/bubbles_short_extended.wav
#     Segmented 242 segments from ../../MicroTex/freesound_class/bubbles/bubbles_long.wav
# Total segments: 301
# Selected 100 segments after random selection
# Processed 100 segments in ../../MicroTex/freesound_class/bubbles
# rain                 bubbles              2.91536
#
# Computed FAD Scores:
# ==================================================
# File 1               File 2               FAD Score
# ==================================================
# keyboard             water                24.36440
# keyboard             wind                 36.11030
# keyboard             fire                 5.20723
# keyboard             rain                 26.07075
# keyboard             bubbles              21.41910
# water                wind                 2.67403
# water                fire                 25.34158
# water                rain                 1.08838
# water                bubbles              2.68151
# wind                 fire                 35.63640
# wind                 rain                 2.35080
# wind                 bubbles              6.45947
# fire                 rain                 28.25837
# fire                 bubbles              23.24597
# rain                 bubbles              2.91536
